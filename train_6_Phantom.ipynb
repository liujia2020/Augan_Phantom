# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 10 \
  --lambda_fft 0\
  --lambda_l1 10 \
  --lambda_gan 0 \
  --lambda_grad 10

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q11_11 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33/test_results_Phantom_03ang

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --netG standard_unet_3d \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 10 \
  --lambda_fft 0\
  --lambda_l1 10 \
  --lambda_gan 0 \
  --lambda_grad 10

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33_Standard/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33_Standard/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33_Standard/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33_Standard/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_GRAD10_33_Standard/test_results_Phantom_03ang

# %%
# !python train.py \
 --dataroot /home/liujia/g_linux/Phantom/ \
 --name Phantom_SSIM100_FFT0_L15_GAN0_GRAD0_33_Standard \
 --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
 --dir_lq Recon_HQ_33 \
 --dir_sq Recon_SQ_75 \
 --batch_size 2 \
 --netG standard_unet_3d \
 --lr 0.0002 \
 --n_epochs 100 \
 --lambda_ssim 100 \
 --lambda_fft 0\
 --lambda_l1 5 \
 --lambda_gan 0 \
 --lambda_grad 0

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM100_FFT0_L15_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM100_FFT0_L15_GAN0_GRAD0_33_Standard/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM100_FFT0_L15_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM100_FFT0_L15_GAN0_GRAD0_33_Standard/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM100_FFT0_L15_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM100_FFT0_L15_GAN0_GRAD0_33_Standard/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM100_FFT0_L15_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM100_FFT0_L15_GAN0_GRAD0_33_Standard/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM100_FFT0_L15_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM100_FFT0_L15_GAN0_GRAD0_33_Standard/test_results_Phantom_03ang

# %%
# !python train.py \
 --dataroot /home/liujia/g_linux/Phantom/ \
 --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
 --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
 --dir_lq Recon_HQ_33 \
 --dir_sq Recon_SQ_75 \
 --batch_size 2 \
 --netG standard_unet_3d \
 --lr 0.0002 \
 --n_epochs 100 \
 --lambda_ssim 100 \
 --lambda_fft 100\
 --lambda_l1 100 \
 --lambda_gan 0 \
 --lambda_grad 0

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard/test_results_Phantom_03ang

# %%
# !python train.py \
 --dataroot /home/liujia/g_linux/Phantom/ \
 --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard \
 --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
 --dir_lq Recon_HQ_33 \
 --dir_sq Recon_SQ_75 \
 --batch_size 2 \
 --netG standard_unet_3d \
 --lr 0.0002 \
 --n_epochs 100 \
 --lambda_ssim 0 \
 --lambda_fft 100\
 --lambda_l1 100 \
 --lambda_gan 30 \
 --lambda_grad 30

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard/test_results_Phantom_03ang

# %%
# !python train.py \
 --dataroot /home/liujia/g_linux/Phantom/ \
 --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
 --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
 --dir_lq Recon_LQ_03 \
 --dir_sq Recon_SQ_75 \
 --batch_size 2 \
 --netG standard_unet_3d \
 --lr 0.0002 \
 --n_epochs 100 \
 --lambda_ssim 100 \
 --lambda_fft 0\
 --lambda_l1 5 \
 --lambda_gan 0 \
 --lambda_grad 0

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard/test_results_Phantom_03ang

# %%
# !python train.py \
 --dataroot /home/liujia/g_linux/Phantom/ \
 --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
 --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
 --dir_lq Recon_LQ_03 \
 --dir_sq Recon_SQ_75 \
 --batch_size 2 \
 --netG standard_unet_3d \
 --lr 0.0002 \
 --n_epochs 100 \
 --lambda_ssim 100 \
 --lambda_fft 0\
 --lambda_l1 5 \
 --lambda_gan 0 \
 --lambda_grad 0

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard/test_results_Phantom_03ang
