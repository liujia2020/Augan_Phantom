# %%
# !python test2.py \
#   --dataroot /home/liujia/g_linux/test/Phantom \
#   --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
#   --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
#   --dir_lq Recon_HQ_33 \
#   --dir_sq Recon_SQ_75 \
#   --epoch 200 \
#   --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q11_11 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0/test_results_Phantom_11ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q07_07 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0/test_results_Phantom_07ang

 
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_Q05_05 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0/test_results_Phantom_05ang
 
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0/test_results_Phantom_03ang
# Out:
# ...
# 🚀 全卷测试 (狸猫换太子策略): Phantom_SSIM0_FFT0_L1100_GAN0
# ...
# >>> 已加载: Anisotropic 3D U-Net (ngf=64)
#
# Processing [1/3]: Carotid_081_mq
#   -> Running inference (Network input is from Recon_Q21_21)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/3]: Phantom_020_mq
#   -> Running inference (Network input is from Recon_Q21_21)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [3/3]: Phantom_050_mq
#   -> Running inference (Network input is from Recon_Q21_21)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# ✅ 测试圆满完成！所有严格对齐的文件和对比图已保存至: /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0/test_results_Phantom_21ang
#
# ...
# 🚀 全卷测试 (狸猫换太子策略): Phantom_SSIM0_FFT0_L1100_GAN0
# ...
# >>> 已加载: Anisotropic 3D U-Net (ngf=64)
#
# Processing [1/3]: Carotid_081_mq
#   -> Running inference (Network input is from Recon_Q15_15)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/3]: Phantom_020_mq
# ...

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33\
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q11_11 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_11ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q07_07 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_07ang

 
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_Q05_05 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_05ang
 
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_03ang
# Out:
# ...
# 🚀 全卷测试 (狸猫换太子策略): Phantom_SSIM0_FFT0_L1100_GAN0_33
# ...
# >>> 已加载: Anisotropic 3D U-Net (ngf=64)
#
# Processing [1/3]: Carotid_081_hq
#   -> Running inference (Network input is from Recon_HQ_33)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/3]: Phantom_020_hq
#   -> Running inference (Network input is from Recon_HQ_33)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [3/3]: Phantom_050_hq
#   -> Running inference (Network input is from Recon_HQ_33)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# ✅ 测试圆满完成！所有严格对齐的文件和对比图已保存至: /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_33ang
#
# ...
# 🚀 全卷测试 (狸猫换太子策略): Phantom_SSIM0_FFT0_L1100_GAN0_33
# ...
# >>> 已加载: Anisotropic 3D U-Net (ngf=64)
#
# Processing [1/3]: Carotid_081_mq
#   -> Running inference (Network input is from Recon_Q21_21)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/3]: Phantom_020_mq
# ...

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33\
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q11_11 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33/test_results_Phantom_11ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q07_07 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33/test_results_Phantom_07ang

 
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_Q05_05 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33/test_results_Phantom_05ang
 
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33/test_results_Phantom_03ang
# Out:
# ...
# 🚀 全卷测试 (狸猫换太子策略): Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33
# ...
# >>> 已加载: Anisotropic 3D U-Net (ngf=64)
#
# Processing [1/3]: Carotid_081_hq
#   -> Running inference (Network input is from Recon_HQ_33)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/3]: Phantom_020_hq
#   -> Running inference (Network input is from Recon_HQ_33)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [3/3]: Phantom_050_hq
#   -> Running inference (Network input is from Recon_HQ_33)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# ✅ 测试圆满完成！所有严格对齐的文件和对比图已保存至: /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33/test_results_Phantom_33ang
#
# ...
# 🚀 全卷测试 (狸猫换太子策略): Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33
# ...
# >>> 已加载: Anisotropic 3D U-Net (ngf=64)
#
# Processing [1/3]: Carotid_081_mq
#   -> Running inference (Network input is from Recon_Q21_21)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/3]: Phantom_020_mq
# ...

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33/test_results_Phantom_11ang
# Out:
# ...
# 🚀 全卷测试 (狸猫换太子策略): Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33
# ...
# >>> 已加载: Anisotropic 3D U-Net (ngf=64)
#
# Processing [1/3]: Carotid_081_mq
#   -> Running inference (Network input is from Recon_MQ_11)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/3]: Phantom_020_mq
#   -> Running inference (Network input is from Recon_MQ_11)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [3/3]: Phantom_050_mq
#   -> Running inference (Network input is from Recon_MQ_11)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# ✅ 测试圆满完成！所有严格对齐的文件和对比图已保存至: /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L1100_GAN1_Angle33/test_results_Phantom_11ang

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_Angle03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q07_07 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L150_GAN1_Angle03/test_results_Phantom_07ang

 
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_Angle03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q05_05 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L150_GAN1_Angle03/test_results_Phantom_05ang
# Out:
# ...
# 🚀 全卷测试 (狸猫换太子策略): Phantom_SSIM10_FFT0.1_L150_GAN1_Angle03
# ...
# >>> 已加载: Anisotropic 3D U-Net (ngf=64)
#
# Processing [1/3]: Carotid_081_mq
#   -> Running inference (Network input is from Recon_Q07_07)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/3]: Phantom_020_mq
#   -> Running inference (Network input is from Recon_Q07_07)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [3/3]: Phantom_050_mq
#   -> Running inference (Network input is from Recon_Q07_07)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# ✅ 测试圆满完成！所有严格对齐的文件和对比图已保存至: /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L150_GAN1_Angle03/test_results_Phantom_07ang
#
# ...
# 🚀 全卷测试 (狸猫换太子策略): Phantom_SSIM10_FFT0.1_L150_GAN1_Angle03
# ...
# >>> 已加载: Anisotropic 3D U-Net (ngf=64)
#
# Processing [1/5]: Carotid_081_mq
#   -> Running inference (Network input is from Recon_Q05_05)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/5]: Phantom_020_mq
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSIM0_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 0 \
  --lambda_fft 0\
  --lambda_l1 10 \
  --lambda_gan 0 

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L110_GAN0_33/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L110_GAN0_33/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L110_GAN0_33/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q11_11 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L110_GAN0_33/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM0_FFT0_L110_GAN0_33/test_results_Phantom_03ang
# Out:
# >>> 实验 [Phantom_SSIM0_FFT0_L110_GAN0_33] 初始化完成，设备: cuda:0
# Dataset Initialized. Found 302 paired volumes (with extra reference).
# >>> 已加载: Anisotropic 3D U-Net
# >>> AUGAN 引擎点火，开始训练！总计划 Epoch: 200
# ✅ Epoch [1/200] 结束 | 耗时: 93.00 秒 | 当前 LR: 0.000200 | D_Total: 0.0367 | G_GAN: 0.0000 | G_L1: 0.1362 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [2/200] 结束 | 耗时: 91.54 秒 | 当前 LR: 0.000200 | D_Total: 0.0483 | G_GAN: 0.0000 | G_L1: 0.1291 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [3/200] 结束 | 耗时: 87.08 秒 | 当前 LR: 0.000200 | D_Total: 0.3903 | G_GAN: 0.0000 | G_L1: 0.1031 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [4/200] 结束 | 耗时: 86.91 秒 | 当前 LR: 0.000200 | D_Total: 0.2442 | G_GAN: 0.0000 | G_L1: 0.0988 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [5/200] 结束 | 耗时: 87.84 秒 | 当前 LR: 0.000200 | D_Total: 0.1841 | G_GAN: 0.0000 | G_L1: 0.1306 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ...

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSIM10_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 10 \
  --lambda_fft 0\
  --lambda_l1 10 \
  --lambda_gan 0 

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_33/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_33/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_33/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q11_11 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_33/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0_L110_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0_L110_GAN0_33/test_results_Phantom_03ang
# Out:
# >>> 实验 [Phantom_SSIM10_FFT0_L110_GAN0_33] 初始化完成，设备: cuda:0
# Dataset Initialized. Found 302 paired volumes (with extra reference).
# >>> 已加载: Anisotropic 3D U-Net
# >>> AUGAN 引擎点火，开始训练！总计划 Epoch: 200
# ✅ Epoch [1/200] 结束 | 耗时: 94.70 秒 | 当前 LR: 0.000200 | D_Total: 0.1236 | G_GAN: 0.0000 | G_L1: 0.1303 | G_SSIM: 0.5163 | G_FFT: 0.0000
# ✅ Epoch [2/200] 结束 | 耗时: 89.96 秒 | 当前 LR: 0.000200 | D_Total: 0.0160 | G_GAN: 0.0000 | G_L1: 0.1072 | G_SSIM: 0.3867 | G_FFT: 0.0000
# ✅ Epoch [3/200] 结束 | 耗时: 91.88 秒 | 当前 LR: 0.000200 | D_Total: 0.0219 | G_GAN: 0.0000 | G_L1: 0.1145 | G_SSIM: 0.3635 | G_FFT: 0.0000
# ✅ Epoch [4/200] 结束 | 耗时: 90.59 秒 | 当前 LR: 0.000200 | D_Total: 0.2886 | G_GAN: 0.0000 | G_L1: 0.1022 | G_SSIM: 0.3170 | G_FFT: 0.0000
# ✅ Epoch [5/200] 结束 | 耗时: 87.40 秒 | 当前 LR: 0.000200 | D_Total: 0.2589 | G_GAN: 0.0000 | G_L1: 0.1359 | G_SSIM: 0.5275 | G_FFT: 0.0000
# ...
