# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2 \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 0 \
  --lambda_fft 0\
  --lambda_l1 100 \
  --lambda_gan 0 

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper2/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_Q21_21 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper2/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_Q15_15 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper2/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_Q11_11 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper2/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper2/Phantom_SSIM0_FFT0_L1100_GAN0_33/test_results_Phantom_03ang

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2 \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 0 \
  --lambda_fft 0\
  --lambda_l1 100 \
  --lambda_gan 0 

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper2/Phantom_SSIM0_FFT0_L1100_GAN0_03/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_Q21_21 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper2/Phantom_SSIM0_FFT0_L1100_GAN0_03/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_Q15_15 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper2/Phantom_SSIM0_FFT0_L1100_GAN0_03/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_Q11_11 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper2/Phantom_SSIM0_FFT0_L1100_GAN0_03/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM0_FFT0_L1100_GAN0_03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper2/ \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper2/Phantom_SSIM0_FFT0_L1100_GAN0_03/test_results_Phantom_03ang
