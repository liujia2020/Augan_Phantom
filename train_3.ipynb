# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSI0_FFT0_L1100_GAN0 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 0 \
  --lambda_fft 0\
  --lambda_l1 100 \
  --lambda_gan 0

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSI0_FFT0_L1100_GAN0 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200
# Out:
# ================================================================================
# 🚀 全卷测试 (Resave All Strategy + Hann Window): Phantom_SSI0_FFT0_L1100_GAN0
# ================================================================================
# Traceback (most recent call last):
#   File "/home/liujia/3DSSIM_FFT/test.py", line 232, in <module>
#     main()
#   File "/home/liujia/3DSSIM_FFT/test.py", line 165, in main
#     if opt.netG == 'standard_unet_3d':
# AttributeError: 'Namespace' object has no attribute 'netG'

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSI0_FFT0_L1100_GAN0_Angle33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 0 \
  --lambda_fft 0\
  --lambda_l1 100 \
  --lambda_gan 0

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSI0_FFT0_L1100_GAN0_Angle33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200
# Out:
# ================================================================================
# 🚀 全卷测试 (Resave All Strategy + Hann Window): Phantom_SSI0_FFT0_L1100_GAN0_Angle33
# ================================================================================
#
# Processing [1/3]: Carotid_081_hq
#   -> Running sliding window inference with Hann weights...
#   -> Saving NIfTI files... (Shape: (1024, 128, 128))
#
# Processing [2/3]: Phantom_020_hq
#   -> Running sliding window inference with Hann weights...
#   -> Saving NIfTI files... (Shape: (1024, 128, 128))
#
# Processing [3/3]: Phantom_050_hq
#   -> Running sliding window inference with Hann weights...
#   -> Saving NIfTI files... (Shape: (1024, 128, 128))
#
# ✅ 测试圆满完成！所有严格对齐的文件和对比图已保存至: /mnt/e/train_data/checkpoints_Paper/Phantom_SSI0_FFT0_L1100_GAN0_Angle33/test_results_epoch_200

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom_1 \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom_1 \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200
