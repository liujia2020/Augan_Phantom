# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu/ \
  --name Simu_SSIM10_FFT0.1_L1100_GAN1 \
  --checkpoints_dir /mnt/g/train_data/checkpoints_Paper \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 10 \
  --lambda_fft 0.1\
  --lambda_l1 100 \
  --lambda_gan 1.0

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Simu \
  --name Simu_SSIM10_FFT0.1_L1100_GAN1 \
  --checkpoints_dir /mnt/g/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu/ \
  --name Simu_SSI0_FFT0_L1100_GAN0_Angle33 \
  --checkpoints_dir /mnt/g/train_data/checkpoints_Paper \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 0 \
  --lambda_fft 0\
  --lambda_l1 100 \
  --lambda_gan 0

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Simu \
  --name Simu_SSI0_FFT0_L1100_GAN0_Angle33 \
  --checkpoints_dir /mnt/g/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/g/train_data/checkpoints_Paper/Simu_SSI0_FFT0_L1100_GAN0_Angle33/test_results_Simu_33ang

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Simu \
  --name Simu_SSIM10_FFT0.1_L1100_GAN1 \
  --checkpoints_dir /mnt/g/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/g/train_data/checkpoints_Paper/Simu_SSIM10_FFT0.1_L1100_GAN1/test_results_Simu_33ang
# Out:
# ...
# 🚀 全卷测试 (狸猫换太子策略): Simu_SSIM10_FFT0.1_L1100_GAN1
# ...
#
# Processing [1/2]: SimData_RF_standard_2_hq
#   -> Running inference (Network input is from Recon_HQ_33)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/2]: SimData_RF_standard_3_hq
#   -> Running inference (Network input is from Recon_HQ_33)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# ✅ 测试圆满完成！所有严格对齐的文件和对比图已保存至: /mnt/g/train_data/checkpoints_Paper/Simu_SSIM10_FFT0.1_L1100_GAN1/test_results_Simu_33ang

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Simu \
  --name Simu_SSIM10_FFT0.1_L1100_GAN1 \
  --checkpoints_dir /mnt/g/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/g/train_data/checkpoints_Paper/Simu_SSIM10_FFT0.1_L1100_GAN1/test_results_Simu_03angb
# Out:
# ...
# 🚀 全卷测试 (狸猫换太子策略): Simu_SSIM10_FFT0.1_L1100_GAN1
# ...
#
# Processing [1/2]: SimData_RF_standard_2_lq
#   -> Running inference (Network input is from Recon_LQ_03)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/2]: SimData_RF_standard_3_lq
#   -> Running inference (Network input is from Recon_LQ_03)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# ✅ 测试圆满完成！所有严格对齐的文件和对比图已保存至: /mnt/g/train_data/checkpoints_Paper/Simu_SSIM10_FFT0.1_L1100_GAN1/test_results_Simu_03ang

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Simu \
  --name Simu_SSIM10_FFT0.1_L1100_GAN1 \
  --checkpoints_dir /mnt/g/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q27_27 \
  --dir_sq Recon_SQ_75 \
  --epoch 200 \
  --results_dir /mnt/g/train_data/checkpoints_Paper/Simu_SSIM10_FFT0.1_L1100_GAN1/test_results_Simu_27ang
# Out:
# ...
# 🚀 全卷测试 (狸猫换太子策略): Simu_SSIM10_FFT0.1_L1100_GAN1
# ...
#
# Processing [1/2]: SimData_RF_standard_2_mq
#   -> Running inference (Network input is from Recon_Q27_27)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/2]: SimData_RF_standard_3_mq
#   -> Running inference (Network input is from Recon_Q27_27)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# ✅ 测试圆满完成！所有严格对齐的文件和对比图已保存至: /mnt/g/train_data/checkpoints_Paper/Simu_SSIM10_FFT0.1_L1100_GAN1/test_results_Simu_27ang

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu/ \
  --name Simu_SSI0_FFT0_L1100_GAN0_Angle33_StandardUnet \
  --checkpoints_dir /mnt/g/train_data/checkpoints_Paper \
  --netG standard_unet_3d \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 0 \
  --lambda_fft 0\
  --lambda_l1 100 \
  --lambda_gan 0
