# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu/ \
  --name Phantom_SSI0_FFT0_L1100_GAN0 \
  --checkpoints_dir /mnt/g/train_data/checkpoints_Paper \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 0 \
  --lambda_fft 0\
  --lambda_l1 100 \
  --lambda_gan 0
# Out:
# >>> 实验 [Phantom_SSI0_FFT0_L1100_GAN0] 初始化完成，设备: cuda:0
# Dataset Initialized. Found 302 paired volumes (with extra reference).
# >>> AUGAN 引擎点火，开始训练！总计划 Epoch: 200
# ✅ Epoch [1/200] 结束 | 耗时: 89.86 秒 | 当前 LR: 0.000200 | D_Total: 0.1940 | G_GAN: 0.0000 | G_L1: 0.1281 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [2/200] 结束 | 耗时: 89.67 秒 | 当前 LR: 0.000200 | D_Total: 0.1343 | G_GAN: 0.0000 | G_L1: 0.1377 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [3/200] 结束 | 耗时: 86.87 秒 | 当前 LR: 0.000200 | D_Total: 0.0119 | G_GAN: 0.0000 | G_L1: 0.1018 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [4/200] 结束 | 耗时: 86.91 秒 | 当前 LR: 0.000200 | D_Total: 0.1561 | G_GAN: 0.0000 | G_L1: 0.1082 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [5/200] 结束 | 耗时: 87.20 秒 | 当前 LR: 0.000200 | D_Total: 0.2875 | G_GAN: 0.0000 | G_L1: 0.1089 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [6/200] 结束 | 耗时: 86.67 秒 | 当前 LR: 0.000200 | D_Total: 0.2801 | G_GAN: 0.0000 | G_L1: 0.1085 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [7/200] 结束 | 耗时: 87.28 秒 | 当前 LR: 0.000200 | D_Total: 0.2698 | G_GAN: 0.0000 | G_L1: 0.0855 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [8/200] 结束 | 耗时: 87.74 秒 | 当前 LR: 0.000200 | D_Total: 0.2536 | G_GAN: 0.0000 | G_L1: 0.0950 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [9/200] 结束 | 耗时: 87.07 秒 | 当前 LR: 0.000200 | D_Total: 0.2808 | G_GAN: 0.0000 | G_L1: 0.1132 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [10/200] 结束 | 耗时: 88.30 秒 | 当前 LR: 0.000200 | D_Total: 0.2708 | G_GAN: 0.0000 | G_L1: 0.1121 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [11/200] 结束 | 耗时: 88.16 秒 | 当前 LR: 0.000200 | D_Total: 0.2568 | G_GAN: 0.0000 | G_L1: 0.1447 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [12/200] 结束 | 耗时: 88.30 秒 | 当前 LR: 0.000200 | D_Total: 0.2948 | G_GAN: 0.0000 | G_L1: 0.0994 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [13/200] 结束 | 耗时: 86.93 秒 | 当前 LR: 0.000200 | D_Total: 0.2546 | G_GAN: 0.0000 | G_L1: 0.1224 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [14/200] 结束 | 耗时: 89.81 秒 | 当前 LR: 0.000200 | D_Total: 0.2575 | G_GAN: 0.0000 | G_L1: 0.0936 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [15/200] 结束 | 耗时: 88.28 秒 | 当前 LR: 0.000200 | D_Total: 0.2501 | G_GAN: 0.0000 | G_L1: 0.0909 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [16/200] 结束 | 耗时: 89.60 秒 | 当前 LR: 0.000200 | D_Total: 0.2567 | G_GAN: 0.0000 | G_L1: 0.0946 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [17/200] 结束 | 耗时: 87.88 秒 | 当前 LR: 0.000200 | D_Total: 0.2642 | G_GAN: 0.0000 | G_L1: 0.0990 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [18/200] 结束 | 耗时: 88.69 秒 | 当前 LR: 0.000200 | D_Total: 0.4268 | G_GAN: 0.0000 | G_L1: 0.1198 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [19/200] 结束 | 耗时: 87.79 秒 | 当前 LR: 0.000200 | D_Total: 0.2653 | G_GAN: 0.0000 | G_L1: 0.1060 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [20/200] 结束 | 耗时: 88.78 秒 | 当前 LR: 0.000200 | D_Total: 0.2477 | G_GAN: 0.0000 | G_L1: 0.0913 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [21/200] 结束 | 耗时: 93.29 秒 | 当前 LR: 0.000200 | D_Total: 0.3311 | G_GAN: 0.0000 | G_L1: 0.1096 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [22/200] 结束 | 耗时: 91.89 秒 | 当前 LR: 0.000200 | D_Total: 0.2905 | G_GAN: 0.0000 | G_L1: 0.0956 | G_SSIM: 0.0000 | G_FFT: 0.0000
# ✅ Epoch [23/200] 结束 | 耗时: 92.05 秒 | 当前 LR: 0.000200 | D_Total: 0.2472 | G_GAN: 0.0000 | G_L1: 0.1005 | G_SSIM: 0.0000 | G_FFT: 0.0000
# Epoch [24/200]:  53%|▌| 80/151 [00:48<00:39,  1.78it/s, D_Total=0.1913, G_GAN=0.

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSI0_FFT0_L1100_GAN_Angle33 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 0 \
  --lambda_fft 0\
  --lambda_l1 100 \
  --lambda_gan 0

# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Phantom_1 \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom_1 \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200
