# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSIM10_FFT0.1_L1100_GAN1 \
  --checkpoints_dir /mnt/g/train_data/checkpoints_Paper \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 10 \
  --lambda_fft 0.1\
  --lambda_l1 100 \
  --lambda_gan 1.0
# Out:
# >>> 实验 [Phantom_SSIM10_FFT0.1_L1100_GAN1] 初始化完成，设备: cuda:0
# Traceback (most recent call last):
#   File "/home/liujia/3DSSIM_1/Augan_Phantom/train.py", line 226, in <module>
#     main()
#   File "/home/liujia/3DSSIM_1/Augan_Phantom/train.py", line 84, in main
#     dataset = UltrasoundDataset(dataroot=opt.dataroot, dir_lq=opt.dir_lq, dir_sq=opt.dir_sq, patch_size=patch_size)
#   File "/home/liujia/3DSSIM_1/Augan_Phantom/data/dataset.py", line 31, in __init__
#     assert len(self.lq_paths) == len(self.sq_paths), f"文件数量不匹配! LQ={len(self.lq_paths)}, SQ={len(self.sq_paths)}"
# AssertionError: 文件数量不匹配! LQ=274, SQ=302
