# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Simu_3_33_75/ \
  --name AUGAN_MVP_01 \
  --checkpoints_dir /mnt/g/train_data/checkpoints0303 \
  --dir_lq Recon_HQ_33 \
  --epoch 5 \
  --gpu_ids 0

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_Data/ \
  --name AUGAN_MVP_02 \
  --checkpoints_dir /mnt/g/train_data/checkpoints0303 \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 10 \
  --gpu_ids 0
# Out:
# >>> 实验 [AUGAN_MVP_02] 初始化完成，设备: cuda:0
# Dataset Initialized. Found 300 paired volumes.
# >>> AUGAN 引擎点火，开始训练！总计划 Epoch: 200
# ✅ Epoch [1/200] 结束 | 耗时: 193.95 秒 | 当前 LR: 0.000200 | D_Total: 0.0122 | G_GAN: 1.1294 | G_L1: 0.1853 | G_SSIM: 0.8870 | G_FFT: 28.8635
# ✅ Epoch [2/200] 结束 | 耗时: 104.07 秒 | 当前 LR: 0.000200 | D_Total: 0.2362 | G_GAN: 0.2684 | G_L1: 0.0496 | G_SSIM: 0.3246 | G_FFT: 17.7245
# ✅ Epoch [3/200] 结束 | 耗时: 103.56 秒 | 当前 LR: 0.000200 | D_Total: 0.1980 | G_GAN: 0.7307 | G_L1: 0.0763 | G_SSIM: 0.3699 | G_FFT: 20.3207
# ✅ Epoch [4/200] 结束 | 耗时: 105.59 秒 | 当前 LR: 0.000200 | D_Total: 18.7522 | G_GAN: 0.7649 | G_L1: 0.0443 | G_SSIM: 0.2412 | G_FFT: 14.5572
# ✅ Epoch [5/200] 结束 | 耗时: 108.18 秒 | 当前 LR: 0.000200 | D_Total: 0.1795 | G_GAN: 0.3640 | G_L1: 0.0589 | G_SSIM: 0.3314 | G_FFT: 19.0806
# Traceback (most recent call last):
#   File "/home/liujia/3DSSIM_1/Augan_Phantom/train.py", line 223, in <module>
#     main()
#   File "/home/liujia/3DSSIM_1/Augan_Phantom/train.py", line 180, in main
#     'D_Total': loss_D.item(),
# KeyboardInterrupt
# ^C
