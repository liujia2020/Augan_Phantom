# %%
# !python test.py \
  --dataroot /home/liujia/g_linux/test/Simu_3_33_75/ \
  --name AUGAN_MVP_01 \
  --checkpoints_dir /mnt/g/train_data/checkpoints0303 \
  --dir_lq Recon_HQ_33 \
  --epoch 5 \
  --gpu_ids 0

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Simu_Data/ \
  --name AUGAN_MVP_02 \
  --checkpoints_dir /mnt/g/train_data/checkpoints0303 \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --patch_size_d 128 \
  --patch_size_h 64 \
  --patch_size_w 64 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 10 \
  --gpu_ids 0
