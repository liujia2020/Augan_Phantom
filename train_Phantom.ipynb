# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 10 \
  --lambda_fft 0.1\
  --lambda_l1 50 \
  --lambda_gan 1.0
# Out:
# >>> 实验 [Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03] 初始化完成，设备: cuda:0
# Dataset Initialized. Found 302 paired volumes (with extra reference).
# >>> 已加载: Anisotropic 3D U-Net
# >>> AUGAN 引擎点火，开始训练！总计划 Epoch: 200
# ✅ Epoch [1/200] 结束 | 耗时: 89.91 秒 | 当前 LR: 0.000200 | D_Total: 0.0414 | G_GAN: 0.8555 | G_L1: 0.1967 | G_SSIM: 0.9353 | G_FFT: 48.5190
# ✅ Epoch [2/200] 结束 | 耗时: 86.51 秒 | 当前 LR: 0.000200 | D_Total: 0.0177 | G_GAN: 1.0632 | G_L1: 0.1974 | G_SSIM: 0.9598 | G_FFT: 44.2190
# ✅ Epoch [3/200] 结束 | 耗时: 87.16 秒 | 当前 LR: 0.000200 | D_Total: 0.0882 | G_GAN: 0.5875 | G_L1: 0.1890 | G_SSIM: 0.8838 | G_FFT: 43.2676
# ✅ Epoch [4/200] 结束 | 耗时: 86.64 秒 | 当前 LR: 0.000200 | D_Total: 3.0299 | G_GAN: 0.7388 | G_L1: 0.2012 | G_SSIM: 0.9695 | G_FFT: 47.3427
# ✅ Epoch [5/200] 结束 | 耗时: 85.68 秒 | 当前 LR: 0.000200 | D_Total: 0.2888 | G_GAN: 0.3677 | G_L1: 0.2174 | G_SSIM: 0.9635 | G_FFT: 41.8150
# ...

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03/test_results_Phantom_03ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03/test_results_Phantom_15ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03/test_results_Phantom_21ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q27_27 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03/test_results_Phantom_27ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03/test_results_Phantom_33ang
# Out:
# ...
# 🚀 全卷测试 (狸猫换太子策略): Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03
# ...
# >>> 已加载: Anisotropic 3D U-Net (ngf=64)
#
# Processing [1/3]: Carotid_081_lq
#   -> Running inference (Network input is from Recon_LQ_03)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/3]: Phantom_020_lq
#   -> Running inference (Network input is from Recon_LQ_03)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [3/3]: Phantom_050_lq
#   -> Running inference (Network input is from Recon_LQ_03)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# ✅ 测试圆满完成！所有严格对齐的文件和对比图已保存至: /mnt/e/train_data/checkpoints_Paper/Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03/test_results_Phantom_03ang
#
# ...
# 🚀 全卷测试 (狸猫换太子策略): Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03
# ...
# >>> 已加载: Anisotropic 3D U-Net (ngf=64)
#
# Processing [1/3]: Carotid_081_mq
#   -> Running inference (Network input is from Recon_MQ_11)...
#   -> Saving NIfTI files: 03, Generated, 75...
#
# Processing [2/3]: Phantom_020_mq
# ...

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom_1 \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200

# %%
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom_1 \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
  --dir_sq Recon_SQ_75 \
  --epoch 200

# %%
# !python train.py \
  --dataroot /home/liujia/g_linux/Phantom/ \
  --name Phantom_SSIM10_FFT0.1_L150_GAN1_1_Angle03 \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper \
  --dir_lq Recon_LQ_03 \
  --dir_sq Recon_SQ_75 \
  --batch_size 2 \
  --lr 0.0002 \
  --n_epochs 100 \
  --lambda_ssim 0 \
  --lambda_fft 0\
  --lambda_l1 100 \
  --lambda_gan 0
