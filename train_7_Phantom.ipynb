# %%
# !python train.py \
 --dataroot /home/liujia/g_linux/Phantom/ \
 --name 1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
 --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
 --dir_lq Recon_HQ_33 \
 --dir_sq Recon_SQ_75 \
 --batch_size 2 \
 --netG standard_unet_3d \
 --lr 0.0002 \
 --n_epochs 100 \
 --lambda_ssim 0 \
 --lambda_fft 100\
 --lambda_l1 100 \
 --lambda_gan 0 \
 --lambda_grad 0

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard/test_results_Phantom_03ang
# Out:
# >>> 实验 [1_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_33_Standard] 初始化完成，设备: cuda:0
# Dataset Initialized. Found 302 paired volumes (with extra reference).
# >>> 已加载: Standard 3D U-Net (Baseline)
# >>> AUGAN 引擎点火，开始训练！总计划 Epoch: 200
# ✅ Epoch [1/200] 结束 | 耗时: 92.88 秒 | 当前 LR: 0.000200 | D_Total: 0.0344 | G_GAN: 0.0000 | G_L1: 0.4860 | G_SSIM: 0.0000 | G_FFT: 28.8827 | G_Grad: 0.0000
# ✅ Epoch [2/200] 结束 | 耗时: 85.96 秒 | 当前 LR: 0.000200 | D_Total: 0.0064 | G_GAN: 0.0000 | G_L1: 0.3475 | G_SSIM: 0.0000 | G_FFT: 32.0603 | G_Grad: 0.0000
# ✅ Epoch [3/200] 结束 | 耗时: 86.80 秒 | 当前 LR: 0.000200 | D_Total: 0.0482 | G_GAN: 0.0000 | G_L1: 0.4616 | G_SSIM: 0.0000 | G_FFT: 37.4737 | G_Grad: 0.0000
# ✅ Epoch [4/200] 结束 | 耗时: 87.20 秒 | 当前 LR: 0.000200 | D_Total: 0.0381 | G_GAN: 0.0000 | G_L1: 0.4051 | G_SSIM: 0.0000 | G_FFT: 32.4213 | G_Grad: 0.0000
# ✅ Epoch [5/200] 结束 | 耗时: 85.18 秒 | 当前 LR: 0.000200 | D_Total: 0.2391 | G_GAN: 0.0000 | G_L1: 0.3249 | G_SSIM: 0.0000 | G_FFT: 34.6696 | G_Grad: 0.0000
# ...

# %%
# !python train.py \
 --dataroot /home/liujia/g_linux/Phantom/ \
 --name 2_Phantom_SSIM0_FFT0_L1100_GAN30_GRAD30_33_Standard \
 --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
 --dir_lq Recon_HQ_33 \
 --dir_sq Recon_SQ_75 \
 --batch_size 2 \
 --netG standard_unet_3d \
 --lr 0.0002 \
 --n_epochs 100 \
 --lambda_ssim 0 \
 --lambda_fft 0\
 --lambda_l1 100 \
 --lambda_gan 30 \
 --lambda_grad 30

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 2_Phantom_SSIM0_FFT0_L1100_GAN30_GRAD30_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/2_Phantom_SSIM0_FFT0_L1100_GAN30_GRAD30_33_Standard/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 2_Phantom_SSIM0_FFT0_L1100_GAN30_GRAD30_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/2_Phantom_SSIM0_FFT0_L1100_GAN30_GRAD30_33_Standard/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 2_Phantom_SSIM0_FFT0_L1100_GAN30_GRAD30_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/2_Phantom_SSIM0_FFT0_L1100_GAN30_GRAD30_33_Standard/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 2_Phantom_SSIM0_FFT0_L1100_GAN30_GRAD30_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/2_Phantom_SSIM0_FFT0_L1100_GAN30_GRAD30_33_Standard/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 2_Phantom_SSIM0_FFT0_L1100_GAN30_GRAD30_33_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/2_Phantom_SSIM0_FFT0_L1100_GAN30_GRAD30_33_Standard/test_results_Phantom_03ang
# Out:
# >>> 实验 [2_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_33_Standard] 初始化完成，设备: cuda:0
# Dataset Initialized. Found 302 paired volumes (with extra reference).
# >>> 已加载: Standard 3D U-Net (Baseline)
# >>> AUGAN 引擎点火，开始训练！总计划 Epoch: 200
# ✅ Epoch [1/200] 结束 | 耗时: 88.13 秒 | 当前 LR: 0.000200 | D_Total: 0.0936 | G_GAN: 1.0549 | G_L1: 0.4134 | G_SSIM: 0.0000 | G_FFT: 36.3307 | G_Grad: 0.9889
# ✅ Epoch [2/200] 结束 | 耗时: 87.13 秒 | 当前 LR: 0.000200 | D_Total: 0.0230 | G_GAN: 1.0401 | G_L1: 0.3815 | G_SSIM: 0.0000 | G_FFT: 31.7266 | G_Grad: 0.9898
# ✅ Epoch [3/200] 结束 | 耗时: 86.59 秒 | 当前 LR: 0.000200 | D_Total: 0.0262 | G_GAN: 1.1283 | G_L1: 0.3607 | G_SSIM: 0.0000 | G_FFT: 35.5990 | G_Grad: 0.9522
# ✅ Epoch [4/200] 结束 | 耗时: 85.46 秒 | 当前 LR: 0.000200 | D_Total: 0.2861 | G_GAN: 0.2890 | G_L1: 0.3764 | G_SSIM: 0.0000 | G_FFT: 35.0006 | G_Grad: 1.0491
# ✅ Epoch [5/200] 结束 | 耗时: 87.79 秒 | 当前 LR: 0.000200 | D_Total: 0.2292 | G_GAN: 0.3691 | G_L1: 0.3132 | G_SSIM: 0.0000 | G_FFT: 36.0924 | G_Grad: 1.0622
# ...

# %%
# !python train.py \
 --dataroot /home/liujia/g_linux/Phantom/ \
 --name 3_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
 --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
 --dir_lq Recon_LQ_03 \
 --dir_sq Recon_SQ_75 \
 --batch_size 2 \
 --netG standard_unet_3d \
 --lr 0.0002 \
 --n_epochs 100 \
 --lambda_ssim 0 \
 --lambda_fft 100 \
 --lambda_l1 100 \
 --lambda_gan 0 \
 --lambda_grad 0

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 3_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/3_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 3_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/3_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 3_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/3_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 3_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/3_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 3_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/3_Phantom_SSIM0_FFT100_L1100_GAN0_GRAD0_03_Standard/test_results_Phantom_03ang

# %%
# !python train.py \
 --dataroot /home/liujia/g_linux/Phantom/ \
 --name 4_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
 --checkpoints_dir /mnt/e/train_data/checkpoints_Paper\
 --dir_lq Recon_LQ_03 \
 --dir_sq Recon_SQ_75 \
 --batch_size 2 \
 --netG standard_unet_3d \
 --lr 0.0002 \
 --n_epochs 100 \
 --lambda_ssim 0 \
 --lambda_fft 100\
 --lambda_l1 100 \
 --lambda_gan 30 \
 --lambda_grad 30

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 4_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_HQ_33 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/4_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard/test_results_Phantom_33ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 4_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q21_21 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/4_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard/test_results_Phantom_21ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 4_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_Q15_15 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/4_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard/test_results_Phantom_15ang

# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 4_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_MQ_11 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/4_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard/test_results_Phantom_11ang
  
# !python test2.py \
  --dataroot /home/liujia/g_linux/test/Phantom \
  --name 4_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard \
  --checkpoints_dir /mnt/e/train_data/checkpoints_Paper/ \
  --dir_lq Recon_LQ_03 \
    --netG standard_unet_3d \
  --dir_sq Recon_SQ_75 \
  --epoch 200\
  --results_dir /mnt/e/train_data/checkpoints_Paper/4_Phantom_SSIM0_FFT100_L1100_GAN30_GRAD30_03_Standard/test_results_Phantom_03ang
